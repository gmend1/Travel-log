# %% [markdown]
# # U.S.A Travel Log

# %% [markdown]
# This is a travel log for the US only. It starts off in San Diego because that is where we are currently located and it asks you about your experience and rating. If you want to add more city and states, you can! Don't worry we keep track of your average rating as well! And at the end it gives you a random state that you should visit if you are feeling adventurous. I made this for  myself because I've traveled to a lot of places and it felt like it could be useful to me when I go traveling this summer!

# %% [markdown]
# ## Project Code

# %%
import travel
travel.main()
travel.travel_random() # your module.py file
# Out:
# Current Destination: San Diego, California
# Rating (1 - 10):  8.5
# Your experience in San Diego:  Good
# Do you want to add a new city? (y/n):  y
# State:  ca
# City:  LA
# Rating (1 - 10):  9
# Experience:  good
# Do you want to add a new city? (y/n):  n
# Travel Log:
# ---------------
# State: California
# City: San Diego
# Rating: 8.5
# Experience: Good
# <-><-><-><-><-><-><-><-><-><->
# State: California
# City: La
# Rating: 9.0
# Experience: good
# <-><-><-><-><-><-><-><-><-><->
#
# Average rating: 8.75
#
# Ready for an Adventure?
# -----------------------
# Your next destination is: West Virginia!

# %% [markdown]
# #### Testing
#
# This is to test my code!

# %%
# test it out
import unittest
import test_travel

suite = unittest.TestLoader().loadTestsFromModule(test_travel)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_average_rating (test_travel.TestTravelLog.test_average_rating) ... ok
# test_average_rating_with_none (test_travel.TestTravelLog.test_average_rating_with_none) ... ok
# test_state_abbreviation (test_travel.TestTravelLog.test_state_abbreviation) ... ok
# test_state_whitespace (test_travel.TestTravelLog.test_state_whitespace) ... ok
# test_unknown_state (test_travel.TestTravelLog.test_unknown_state) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.007s
#
# OK
# <unittest.runner.TextTestResult run=5 errors=0 failures=0>

# %% [markdown]
# #### GenAI Statement
#
# I used ChatGPT for 60% of the project. It helped me generate the unitest portion, numpy style docstrings, generate lists in the code (states). It also helped me with some parts I was confused on for the project.

# %% [markdown]
# #### Extra Credit (*optional*)
# 1. I have no experience with python or coding in general. This is my first class for coding.
# 2. I learned how to use the input, strip, title. I also did 5 functions instead of the required 3. It challenged me because I had to push myself to learn new functions and how to cohesively put together codes.
